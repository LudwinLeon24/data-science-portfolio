# %%
import pandas as pd # Read and analize data Excel, CSV, etc.
import numpy as np # Quick mathematical operations
import seaborn as sns # Quick graphics
import matplotlib.pyplot as plt # Complex graphics

data_0 = pd.read_csv('exped.csv')  # Reading all the CSV files
data_1 = pd.read_csv('himalayan_data_dictionary.csv')
data_2 = pd.read_csv('members.csv')
data_3 = pd.read_csv('peaks.csv')

dataframes = [data_0, data_1, data_2, data_3] # A list with the dataframes 
                                            #so I can iterate over them in specific to fullfill the Naan data and to display the information with a loop

for i, df in enumerate(dataframes): # [for loop, iterate in all datas ASAP]
    dataframes[i] = df.fillna('unknown') # replace Nan with unknown
    print(f" Data {i}")
    display(dataframes[i].head(5))
    display(dataframes[i].shape)  
    display(dataframes[i].dtypes)
    display(dataframes[i].drop_duplicates())
    display(dataframes[i].describe())
    print("\n")
    print("\n")
    print("\n")
# Out:
# C:\Users\Ludwin Leon\AppData\Local\Temp\ipykernel_11524\249246472.py:6: DtypeWarning: Columns (8,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_0 = pd.read_csv('exped.csv')  # I am  reading all the CSV files
#  Data 0
# C:\Users\Ludwin Leon\AppData\Local\Temp\ipykernel_11524\249246472.py:8: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2 = pd.read_csv('members.csv')
#        expid peakid  year  season   host            route1            route2  \
# 0  ANN260101   ANN2  1960  Spring  Nepal  NW Ridge-W Ridge           unknown
# 1  ANN269301   ANN2  1969  Autumn  Nepal  NW Ridge-W Ridge           unknown
# 2  ANN273101   ANN2  1973  Spring  Nepal    W Ridge-N Face           unknown
# 3  ANN278301   ANN2  1978  Autumn  Nepal    N Face-W Ridge           unknown
# 4  ANN279301   ANN2  1979  Autumn  Nepal    N Face-W Ridge  NW Ridge of A-IV
#
# ...
